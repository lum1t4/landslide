# %%
from itertools import product
from pathlib import Path

datas = [
    'data/processed/csv_split/A19_5cm.yml' ,
    'data/processed/csv_split/Avigliano_5cm.yml' ,
    'data/processed/csv_split/Avigliano2_5_cm.yml' ,
    'data/processed/csv_split/Bella_5cm.yml' ,
    'data/processed/csv_split/Bella3_5cm.yml' ,
    'data/processed/csv_split/Corleto_Perticara_5cm.yml' ,
    'data/processed/csv_split/Ferrandina2_5cm.yml' ,
    'data/processed/csv_split/Genzano_Lucania_5cm.yml' ,
    'data/processed/csv_split/Grassano_5cm.yml' ,
    'data/processed/csv_split/Ischia_5cm.yml' ,
    'data/processed/csv_split/Miglionico_5cm.yml' ,
    'data/processed/csv_split/Montescaglioso_5cm.yml' ,
    'data/processed/csv_split/Pietragalla_5cm.yml' ,
    'data/processed/csv_split/Pomarico_5cm.yml' ,
    'data/processed/csv_split/Provincia_Taranto_Ginosa_5cm.yml' ,
    'data/processed/csv_split/Provincia_Taranto_Montemesola_5cm_1.yml' ,
    'data/processed/csv_split/Provincia_Taranto_Montemesola_5cm_2.yml' ,
    'data/processed/csv_split/Provincia_Taranto_Montemesola_5cm_3.yml' ,
    'data/processed/csv_split/Stigliano_5cm.yml' ,
    'data/processed/csv_split/Stigliano2_5cm.yml' ,
    'data/processed/csv_split/Stigliano3_5cm.yml' ,
    'data/processed/csv_split/Stigliano4_5cm.yml',
]
losses = ["bce", "focal_loss", "bce+dice", "bce+lovasz"]
models = ["unet"]


NUM_GPUS = 1
for i, (data, loss, model) in enumerate(product(datas, losses, models)):
    dix = i % NUM_GPUS

    imgsz = 512
    masksz = 128

    if model == "unet":
        imgsz = masksz
    
    base = f"uv run scripts/recipe.py --config 'config/base.yml' --model '{model}' --dataset '{data}' --criterion '{loss}' --device 'cuda:{dix}' --imgsz {imgsz} --masksz {masksz}"
    print(base)
# Out:
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/A19_5cm.yml' --criterion 'bce' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/A19_5cm.yml' --criterion 'focal_loss' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/A19_5cm.yml' --criterion 'bce+dice' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/A19_5cm.yml' --criterion 'bce+lovasz' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Avigliano_5cm.yml' --criterion 'bce' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Avigliano_5cm.yml' --criterion 'focal_loss' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Avigliano_5cm.yml' --criterion 'bce+dice' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Avigliano_5cm.yml' --criterion 'bce+lovasz' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Avigliano2_5_cm.yml' --criterion 'bce' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Avigliano2_5_cm.yml' --criterion 'focal_loss' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Avigliano2_5_cm.yml' --criterion 'bce+dice' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Avigliano2_5_cm.yml' --criterion 'bce+lovasz' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Bella_5cm.yml' --criterion 'bce' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Bella_5cm.yml' --criterion 'focal_loss' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Bella_5cm.yml' --criterion 'bce+dice' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Bella_5cm.yml' --criterion 'bce+lovasz' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Bella3_5cm.yml' --criterion 'bce' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Bella3_5cm.yml' --criterion 'focal_loss' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Bella3_5cm.yml' --criterion 'bce+dice' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Bella3_5cm.yml' --criterion 'bce+lovasz' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Corleto_Perticara_5cm.yml' --criterion 'bce' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Corleto_Perticara_5cm.yml' --criterion 'focal_loss' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Corleto_Perticara_5cm.yml' --criterion 'bce+dice' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Corleto_Perticara_5cm.yml' --criterion 'bce+lovasz' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Ferrandina2_5cm.yml' --criterion 'bce' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Ferrandina2_5cm.yml' --criterion 'focal_loss' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Ferrandina2_5cm.yml' --criterion 'bce+dice' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Ferrandina2_5cm.yml' --criterion 'bce+lovasz' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Genzano_Lucania_5cm.yml' --criterion 'bce' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Genzano_Lucania_5cm.yml' --criterion 'focal_loss' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Genzano_Lucania_5cm.yml' --criterion 'bce+dice' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Genzano_Lucania_5cm.yml' --criterion 'bce+lovasz' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Grassano_5cm.yml' --criterion 'bce' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Grassano_5cm.yml' --criterion 'focal_loss' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Grassano_5cm.yml' --criterion 'bce+dice' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Grassano_5cm.yml' --criterion 'bce+lovasz' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Ischia_5cm.yml' --criterion 'bce' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Ischia_5cm.yml' --criterion 'focal_loss' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Ischia_5cm.yml' --criterion 'bce+dice' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Ischia_5cm.yml' --criterion 'bce+lovasz' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Miglionico_5cm.yml' --criterion 'bce' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Miglionico_5cm.yml' --criterion 'focal_loss' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Miglionico_5cm.yml' --criterion 'bce+dice' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Miglionico_5cm.yml' --criterion 'bce+lovasz' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Montescaglioso_5cm.yml' --criterion 'bce' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Montescaglioso_5cm.yml' --criterion 'focal_loss' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Montescaglioso_5cm.yml' --criterion 'bce+dice' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Montescaglioso_5cm.yml' --criterion 'bce+lovasz' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Pietragalla_5cm.yml' --criterion 'bce' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Pietragalla_5cm.yml' --criterion 'focal_loss' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Pietragalla_5cm.yml' --criterion 'bce+dice' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Pietragalla_5cm.yml' --criterion 'bce+lovasz' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Pomarico_5cm.yml' --criterion 'bce' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Pomarico_5cm.yml' --criterion 'focal_loss' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Pomarico_5cm.yml' --criterion 'bce+dice' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Pomarico_5cm.yml' --criterion 'bce+lovasz' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Provincia_Taranto_Ginosa_5cm.yml' --criterion 'bce' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Provincia_Taranto_Ginosa_5cm.yml' --criterion 'focal_loss' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Provincia_Taranto_Ginosa_5cm.yml' --criterion 'bce+dice' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Provincia_Taranto_Ginosa_5cm.yml' --criterion 'bce+lovasz' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Provincia_Taranto_Montemesola_5cm_1.yml' --criterion 'bce' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Provincia_Taranto_Montemesola_5cm_1.yml' --criterion 'focal_loss' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Provincia_Taranto_Montemesola_5cm_1.yml' --criterion 'bce+dice' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Provincia_Taranto_Montemesola_5cm_1.yml' --criterion 'bce+lovasz' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Provincia_Taranto_Montemesola_5cm_2.yml' --criterion 'bce' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Provincia_Taranto_Montemesola_5cm_2.yml' --criterion 'focal_loss' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Provincia_Taranto_Montemesola_5cm_2.yml' --criterion 'bce+dice' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Provincia_Taranto_Montemesola_5cm_2.yml' --criterion 'bce+lovasz' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Provincia_Taranto_Montemesola_5cm_3.yml' --criterion 'bce' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Provincia_Taranto_Montemesola_5cm_3.yml' --criterion 'focal_loss' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Provincia_Taranto_Montemesola_5cm_3.yml' --criterion 'bce+dice' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Provincia_Taranto_Montemesola_5cm_3.yml' --criterion 'bce+lovasz' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Stigliano_5cm.yml' --criterion 'bce' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Stigliano_5cm.yml' --criterion 'focal_loss' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Stigliano_5cm.yml' --criterion 'bce+dice' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Stigliano_5cm.yml' --criterion 'bce+lovasz' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Stigliano2_5cm.yml' --criterion 'bce' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Stigliano2_5cm.yml' --criterion 'focal_loss' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Stigliano2_5cm.yml' --criterion 'bce+dice' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Stigliano2_5cm.yml' --criterion 'bce+lovasz' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Stigliano3_5cm.yml' --criterion 'bce' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Stigliano3_5cm.yml' --criterion 'focal_loss' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Stigliano3_5cm.yml' --criterion 'bce+dice' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Stigliano3_5cm.yml' --criterion 'bce+lovasz' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Stigliano4_5cm.yml' --criterion 'bce' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Stigliano4_5cm.yml' --criterion 'focal_loss' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Stigliano4_5cm.yml' --criterion 'bce+dice' --device 'cuda:0'
# uv run scripts/recipe.py --config 'config/base.yml' --dataset 'data/processed/csv_split/Stigliano4_5cm.yml' --criterion 'bce+lovasz' --device 'cuda:0'
